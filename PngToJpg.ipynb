# %%
from glob import glob
import os
from PIL import Image

# %%
train_image_path = glob("./images/train/*.png")
test_image_path = glob("./images/test/*.png")
val_image_path = glob("./images/val/*.png")

# %%
one_train_image = Image.open(train_image_path[0])
one_train_image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=550x550 at 0x7EFE821AD810>

# %%
for path in val_image_path:
    new_path = "."+path.split('.')[1]+".jpg"
    
    
    img_pil = Image.open(path)
    img_pil.save(new_path)
