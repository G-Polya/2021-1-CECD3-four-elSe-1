# %%
from EfficientDet import *
import cv2
from glob import glob
import matplotlib.pyplot as plt

# %%
detector_model_d2 = get_detector('https://tfhub.dev/tensorflow/efficientdet/d2/1')
# Out:
# WARNING:absl:Importing a function (__inference_EfficientDet-D2_layer_call_and_return_conditional_losses_130857) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_EfficientDet-D2_layer_call_and_return_conditional_losses_130857) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_EfficientDet-D2_layer_call_and_return_conditional_losses_130857) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_EfficientDet-D2_layer_call_and_return_conditional_losses_130857) with ops with custom gradients. Will likely fail if a gradient is requested.
# WARNING:absl:Importing a function (__inference_EfficientDet-D2_layer_call_and_return_conditional_losses_130857) with ops with custom gradients. Will likely fail if a gradient is requested.
# ...

# %%
image_paths = glob("./*.png")

formatList, draw_imgs = get_detected_img(model=detector_model_d2, 
                                         inputData_list=image_paths, 
                                         output_path="./")
# Out:
# vase: 0.7314
# Detection 수행시간: 7.41 초
# potted plant: 0.6611
# Detection 수행시간: 7.42 초
# vase: 0.5440
# Detection 수행시간: 7.42 초
# vase: 0.4340
# Detection 수행시간: 7.43 초
# chair: 0.7973
# Detection 수행시간: 0.11 초
# bottle: 0.5691
# Detection 수행시간: 0.12 초
# bottle: 0.5668
# Detection 수행시간: 0.13 초
# vase: 0.5588
# Detection 수행시간: 0.13 초
# vase: 0.5334
# Detection 수행시간: 0.14 초

# %%
plt.imshow(draw_imgs[1])

# %%
formatList[0]
# Out:
# {'objectID': 'a4faeff5-ec7f-4d23-801e-7aa2e77cc467',
#  'location': {'xmin': 99, 'ymin': 325, 'xmax': 201, 'ymax': 384},
#  'tag': 'vase',
#  'objectImagaPath': './_vase.jpg',
#  'IMG_URL': './100356.png'}
